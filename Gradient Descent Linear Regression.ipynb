# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import preprocessing

# %%
df = pd.read_csv('weight-height.csv')
x = df.iloc[:, 1]
y = df.iloc[:, 2]

# %%
df.sample(10)
# Out:
#       Gender     Height      Weight
# 262     Male  70.993144  204.746678
# 8783  Female  62.686276  130.120433
# 8425  Female  62.615281  117.439002
# 8337  Female  61.792657  107.455066
# 4521    Male  67.042903  182.721452
# 6797  Female  65.025611  136.853111
# 9095  Female  66.249361  140.799489
# 4718    Male  69.203429  186.393762
# 8416  Female  64.637493  133.379546
# 6646  Female  68.225407  162.924772

# %%
df.isnull().sum()
# Out:
# Gender    0
# Height    0
# Weight    0
# dtype: int64

# %%
# %matplotlib notebook
plt.figure()
plt.hist(x)
plt.title('Height Histogram')
plt.xlabel('Height')
plt.ylabel('Total Count')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.hist(y)
plt.title('Weight Histogram')
plt.xlabel('Weight')
plt.ylabel('Total Count')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.scatter(x, y)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
lr = 0.0001
Epochs = 1000
n = float(len(x))
theta_0 = 20
theta_1 = 0

# %%
def derivative_theta_0(x, y, y_p, n):
    return (-1/n) * sum(y - y_p)

# %%
def derivative_theta_1(x, y, y_p, n):
    return (-1/n) * sum((y - y_p) * x)

# %%
store_theta_0 = []
store_theta_1 = []

for i in range(Epochs):
    y_p = theta_0 + theta_1 * x
    theta_0 = theta_0 - lr * derivative_theta_0(x, y, y_p, n)
    theta_1 = theta_1 - lr * derivative_theta_1(x, y, y_p, n)
    store_theta_0.append(theta_0)
    store_theta_1.append(theta_1)
    
print(theta_0)
print(theta_1)
# Out:
# 19.908145355802777
# 2.1512517130299718

# %%
y_pred = theta_0 + theta_1 * x

plt.figure()
plt.scatter(x, y)
plt.plot([min(x), max(x)], [min(y_pred), max(y_pred)], color='r')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
